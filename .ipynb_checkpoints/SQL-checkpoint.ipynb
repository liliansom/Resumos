# %% [markdown]
# # Resumo SQL

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # O que significam as siglas: DDL, DML, DQL, DTL e DCL?

# %%
dados = {'Siglas': ['DDL', 'DML', 'DQL', 'DTL', 'DCL'],
         'Definição': ['Data Definition Language', 'Data Manipulation Language', 'Data Query Language', 'Data Transaction Language', 'Data Control Language'],
         'Sobre': ['Linguagem de Definição de Dados', 'Linguagem de Manipulação de Dados', 'Linguagem de Consulta de Dados', 'Linguagem de Transação de Dados', 'Linguagem de Controle de Dados'],
         'Comandos': [['CREATE', 'ALTER', 'DROP'], ['INSERT', 'DELETE', 'UPDATE'], ['SELECT'], ['BEGIN TRANSACTION', 'COMMIT', 'ROLLBACK'], ['GRANT', 'REVOKE', 'DENY']]}

df = pd.DataFrame(dados)
df
# Out:
#   Siglas                   Definição                              Sobre  \
# 0    DDL    Data Definition Language    Linguagem de Definição de Dados
# 1    DML  Data Manipulation Language  Linguagem de Manipulação de Dados
# 2    DQL         Data Query Language     Linguagem de Consulta de Dados
# 3    DTL   Data Transaction Language    Linguagem de Transação de Dados
# 4    DCL       Data Control Language     Linguagem de Controle de Dados
#
#                                 Comandos
# 0                  [CREATE, ALTER, DROP]
# 1               [INSERT, DELETE, UPDATE]
# 2                               [SELECT]
# 3  [BEGIN TRANSACTION, COMMIT, ROLLBACK]
# 4                  [GRANT, REVOKE, DENY]

# %% [markdown]
# # Quais são os principais comandos em SQL?

# %%
comandos = {'Comandos': ['SELECT', 'FROM', 'WHERE', 'AS', 'JOIN', 'AND', 'OR', 'LIMIT', 'IN', 'CASE', 'IS NULL', 'LIKE', 'COMMIT', 'ROLLBACK', 'ALTER TABLE', 'UPDATE', 'CREATE', 'DELETE', 'INSERT', 'DROP', 'GROUP BY', 'ORDER BY', 'HAVING', 'COUNT', 'SUM', 'AVG', 'MIN', 'MAX'],
'Descrições': ['Selecionar dados de uma tabela', 'Especificar a tabela de onde estamos buscando', 'Filtrar a consulta para corresponder a uma condição', 'Renomear coluna ou tabela com alias', 'Combinar linhas de duas ou mais tabelas', 'Combinar condições de consulta. Todas devem ser atendidas', 'Combinar condições de consulta. Uma deve ser atendida', 'Limitar as linhas retornadas. Consulte também FETCH e TOP', 'Especificar múltiplos valores ao usar WHERE', 'Retornar valor em uma condição especificada', 'Retornar apenas linhas com valor NULL', 'Pesquisar padrões em coluna', 'Escrever transação no banco de dados', 'Desfazer um bloco de transação', 'Adicionar/Remover colunas de tabela', 'Atualizar dados de tabela', 'Criar TABELA, BANCO DE DADOS, ÍNDICE ou VISÃO', 'Excluir linhas da tabela', 'Adicionar uma única linha à tabela', 'Excluir TABELA, BANCO DE DADOS ou ÍNDICE', 'Agrupar dados em conjuntos lógicos', 'Definir ordem do resultado. Use DESC para inverter a ordem', 'Mesmo que WHERE, mas filtra grupos', 'Contar o número de linhas', 'Retornar a soma da coluna', 'Retornar a média da coluna', 'Retornar o valor mínimo da coluna', 'Retornar o valor máximo da coluna']}

com = pd.DataFrame(comandos)
pd.set_option('display.max_colwidth', 100)
display(com)
# Out:
#        Comandos                                                  Descrições
# 0        SELECT                              Selecionar dados de uma tabela
# 1          FROM               Especificar a tabela de onde estamos buscando
# 2         WHERE         Filtrar a consulta para corresponder a uma condição
# 3            AS                         Renomear coluna ou tabela com alias
# 4          JOIN                     Combinar linhas de duas ou mais tabelas
# 5           AND   Combinar condições de consulta. Todas devem ser atendidas
# 6            OR       Combinar condições de consulta. Uma deve ser atendida
# 7         LIMIT   Limitar as linhas retornadas. Consulte também FETCH e TOP
# 8            IN                 Especificar múltiplos valores ao usar WHERE
# 9          CASE                 Retornar valor em uma condição especificada
# 10      IS NULL                       Retornar apenas linhas com valor NULL
# ...

# %% [markdown]
# # Qual a Ordem de Execução dos principais comandos?

# %%
dados = {'Ordem de Execução': ['FROM', 'WHERE', 'GROUP BY', 'HAVING', 'SELECT', 'ORDER BY', 'LIMIT']}
ordem = pd.DataFrame(dados)
display(ordem)
# Out:
#   Ordem de Execução
# 0              FROM
# 1             WHERE
# 2          GROUP BY
# 3            HAVING
# 4            SELECT
# 5          ORDER BY
# 6             LIMIT

# %% [markdown]
# # Sobre os JOIN's

# %%
imagem = plt.imread("img/sql_join.png")
plt.figure(figsize=(12,10))
plt.imshow(imagem)
plt.show()

# %% [markdown]
# ## FULL JOIN

# %% [markdown]
# ## INNER JOIN

# %% [markdown]
# ## LEFT JOIN

# %% [markdown]
# ## RIGHT JOIN

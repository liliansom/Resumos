# %% [markdown]
# # Fórmulas DAX

# %%
from IPython.display import Image

# %% [markdown]
# # Sintaxe

# %%
imagem_path = "C:/Users/Usuário/Documents/GitHub/Resumos/img/sintaxe_pbi.jpg"
Image(filename=imagem_path, alt="Sintaxe")

# %% [markdown]
# ### Operadores

# %%
imagem_path1 = "C:/Users/Usuário/Documents/GitHub/Resumos/img/operadores_pbi.png"
Image(filename=imagem_path1, alt="Operadores")

# %%
imagem_path1 = "C:/Users/Usuário/Documents/GitHub/Resumos/img/operadores_pbi1.png"
Image(filename=imagem_path2, alt="Operadores")

# %%
imagem_path2 = "C:/Users/Usuário/Documents/GitHub/Resumos/img/operadores_pbi2.png"
Image(filename=imagem_path2, alt="Operadores")

# %%
imagem_path3 = "C:/Users/Usuário/Documents/GitHub/Resumos/img/formulas_dax.jpg"
Image(filename=imagem_path3, alt="FórmulasDax")

# %% [markdown]
# #### Colunas Calculadas
# Os valores são calculados baseados na informação de cada linha da tabela (são calculados invididualmente para cada linha, chamado de "Contexto de linha").
#
# Acrescenta uma nova coluna na tabela
#
# Recalcula de acordo com alterações nas células
#
# Geralmente usado nos campos de Linhas, Colunas Ou Filtros nas Matrizes/Gráficos.

# %% [markdown]
# #### Criação de Medida
# Os valores são calculados baseados nos filtros aplicados nas Matrizes (chamado de "Contexto de Filtro").
#
# Não acrescenta novas colunas na tabela.
#
# Recalcula de acordo com alterações nos filtros do relatório (em uma matriz ou gráfico).
#
# Quase sempre usado no campo Valores de uma Matriz/Gráfico
#
# * Nova Medida
# * Digitar o DAX

# %% [markdown]
# #### Cláusula IF
#
#     Nome da Coluna = if('NomeTabela'[coluna]condição;"ValorTrue";"ValorFalse")
#     condição = >, <, =

# %% [markdown]
# #### Cláusula SUM
#
#     NomeColuna = sum('NomeTabela'[coluna])
